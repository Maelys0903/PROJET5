# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/questions/stack_questions_api.csv
# /kaggle/input/use/tensorflow2/default/1/saved_model.pb
# /kaggle/input/use/tensorflow2/default/1/variables/variables.index
# /kaggle/input/use/tensorflow2/default/1/variables/variables.data-00000-of-00001

# %%
import pandas as pd

# Charger le dataset
df = pd.read_csv("/kaggle/input/questions/stack_questions_api.csv")

# Afficher les colonnes et les premières lignes
print(df.columns)
df.head()
# Out:
# Index(['question_id', 'title', 'body', 'tags', 'creation_date', 'score',
#        'view_count', 'answer_count', 'is_answered'],
#       dtype='object')
#    question_id                                              title  \
# 0     11227809  Why is processing a sorted array faster than p...
# 1       927358  How do I undo the most recent local commits in...
# 2      2003505  How do I delete a Git branch locally and remot...
# 3       292357  What is the difference between &#39;git pull&#...
# 4       231767  What does the &quot;yield&quot; keyword do in ...
#
#                                                 body  \
# 0  <p>In this C++ code, sorting the data (<em>bef...
# 1  <p>I accidentally committed the wrong files to...
# 2  <p>Failed Attempts to Delete a Remote Branch:<...
# 3  <p>What are the differences between <a href="h...
# 4  <p>What functionality does the <a href="https:...
#
#                                                 tags  creation_date  score  \
# 0  ['java', 'c++', 'performance', 'cpu-architectu...     1340805096  27457
# 1   ['git', 'version-control', 'git-commit', 'undo']     1243620554  27061
# 2  ['git', 'version-control', 'git-branch', 'git-...     1262653935  20365
# 3  ['git', 'version-control', 'git-pull', 'git-fe...     1226742669  13995
# 4       ['python', 'iterator', 'generator', 'yield']     1224800471  13086
#
#    view_count  answer_count  is_answered
# 0     1941240            25         True
# 1    16139015           103         True
# 2    12869902            41         True
# 3     3674790            37         True
# 4     3450087            52         True

# %%
import tensorflow_hub as hub

# Charger le modèle localement depuis Kaggle
model = hub.load("/kaggle/input/use/tensorflow2/default/1")

# %%
sentences = ["Hello world", "This is a test"]
embeddings = model(sentences)

# Pour voir la taille de l'encodage (512 dimensions normalement)
print(embeddings.shape)
# Out:
# (2, 512)

# %% [markdown]
# sentences est une liste de 2 phrases.
#
# Le modèle Universal Sentence Encoder (USE) produit un vecteur d'embedding de dimension 512 pour chaque phrase.
#
# Donc embeddings.shape nous donne (2, 512) = 2 phrases × 512 dimensions.

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import f1_score

X = model(df['title'].tolist())
X = np.array(X)

X_train, X_test, y_train, y_test = train_test_split(X, y_filtered, test_size=0.2, random_state=42)

tags_list = [tags.split() for tags in df['tags']]
mlb = MultiLabelBinarizer()
y = mlb.fit_transform(tags_list)

# Analyse fréquence des labels
freq_labels = y.sum(axis=0)
labels_all = np.where(freq_labels == len(y))[0]      # présents dans TOUS les exemples
labels_rare = np.where(freq_labels < 3)[0]           # moins de 3 occurrences
print(f"Labels présents dans tous les exemples : {[mlb.classes_[i] for i in labels_all]}")
print(f"Labels rares (<3 occurrences) : {[mlb.classes_[i] for i in labels_rare]}")

# Filtrage des labels
keep_labels = np.where((freq_labels < len(y)) & (freq_labels >= 3))[0]
y_filtered = y[:, keep_labels]
filtered_classes = [mlb.classes_[i] for i in keep_labels]

print(f"Nombre de labels avant filtre : {len(mlb.classes_)}")
print(f"Nombre de labels après filtre : {len(filtered_classes)}")

clf = OneVsRestClassifier(LogisticRegression(max_iter=1000))
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

f1_micro = f1_score(y_test, y_pred, average='micro', zero_division=0)
f1_macro = f1_score(y_test, y_pred, average='macro', zero_division=0)

print(f"F1-score micro: {f1_micro:.3f}")
print(f"F1-score macro: {f1_macro:.3f}")
# Out:
# Labels présents dans tous les exemples : []
# Labels rares (<3 occurrences) : ["'.net',", "'access-modifiers']", "'actionscript',", "'algorithm',", "'alias']", "'alignment',", "'alignment']", "'android',", "'android-activity',", "'android-edittext',", "'android-emulator',", "'android-input-method',", "'android-layout',", "'android-softkeyboard',", "'angularjs']", "'angularjs-factory',", "'angularjs-provider']", "'angularjs-service',", "'ansi-colors']", "'append',", "'architecture',", "'argument-unpacking']", "'arguments',", "'array-of-dict']", "'arrays']", "'assignment-operator']", "'async-await',", "'asynchronous',", "'asynchronous']", "'authentication',", "'autocomplete']", "'background-color']", "'bash',", "'big-o',", "'bit-manipulation',", "'bitwise-operators']", "'boolean-expression',", "'boolean-operations',", "'branch-prediction']", "'branching-and-merging']", "'browser',", "'browser']", "'c++',", "'c++-faq',", "'c-preprocessor']", "'caret',", "'case-insensitive']", "'centering']", "'chain']", "'char']", "'checkbox',", "'checkbox']", "'checked']", "'cherry-pick',", "'chunks']", "'class',", "'class-method']", "'clipboard',", "'clone',", "'clone']", "'closures']", "'code-formatting',", "'coldfusion',", "'command',", "'command']", "'command-line-arguments']", "'command-line-interface']", "'comments']", "'commit-message']", "'comparison',", "'complexity-theory',", "'computer-science',", "'concatenation',", "'concatenation']", "'conditional-operator']", "'constructor',", "'contains',", "'contains']", "'content-type']", "'copy',", "'copy-paste']", "'cors',", "'cpu-architecture',", "'cross-browser',", "'css']", "'css-selectors']", "'curl',", "'data-structures',", "'dataframe',", "'date',", "'date-arithmetic']", "'date-formatting']", "'decimal-point']", "'decorator',", "'default-parameters',", "'definition']", "'delay',", "'delete-file',", "'delete-file']", "'dependency-injection',", "'dictionary']", "'dimension',", "'display']", "'dml']", "'docker-container',", "'docker-network']", "'dockerfile']", "'dom',", "'dom']", "'dom-events',", "'dynamic-memory-allocation',", "'each']", "'echo',", "'ecmascript-2017']", "'ecmascript-6',", "'editor',", "'emacs',", "'email-validation']", "'enumeration']", "'enums',", "'environment-variables']", "'equality',", "'equality-operator',", "'event-handling',", "'event-propagation']", "'exception',", "'exception']", "'explicit',", "'explicit-constructor']", "'extend']", "'figsize']", "'file-copying']", "'file-exists']", "'filesystems',", "'filter']", "'find']", "'flatten']", "'floating-accuracy']", "'floating-point',", "'focus']", "'for-loop',", "'for-loop']", "'foreach',", "'format',", "'forms',", "'generator',", "'genymotion',", "'git',", "'git-add',", "'git-amend']", "'git-checkout']", "'git-cherry-pick']", "'git-clone',", "'git-clone']", "'git-commit']", "'git-diff']", "'git-filter-branch',", "'git-fork']", "'git-log']", "'git-merge',", "'git-merge']", "'git-merge-conflict']", "'git-pull',", "'git-rebase',", "'git-refspec']", "'git-reset',", "'git-reset']", "'git-restore']", "'git-revert']", "'git-rewrite-history',", "'git-rewrite-history']", "'git-rm']", "'git-show']", "'git-squash']", "'git-stash',", "'git-stash']", "'git-submodules']", "'git-tag']", "'github',", "'github-flavored-markdown']", "'gitignore',", "'global-variables',", "'grep',", "'guid',", "'hashmap',", "'hashtable']", "'header-files',", "'heap-memory',", "'heredoc']", "'highlight',", "'href']", "'html-input']", "'html-table',", "'http-get']", "'http-headers']", "'http-redirect']", "'http-response-codes']", "'http-status-code-401',", "'http-status-code-403',", "'http-status-codes',", "'identity-operator']", "'idioms']", "'import',", "'include',", "'include']", "'indexing',", "'indexing']", "'inheritance',", "'initialization']", "'inner-join',", "'inputstream']", "'io',", "'is-empty']", "'iterator',", "'join',", "'jquery']", "'jslint',", "'json',", "'junit',", "'key',", "'key']", "'language-agnostic']", "'language-design',", "'least-astonishment']", "'let']", "'linked-list' ...
# Nombre de labels avant filtre : 495
# Nombre de labels après filtre : 63
# F1-score micro: 0.291
# F1-score macro: 0.029
